# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Snake Recognizer Project
# Out:
# /content/drive/My Drive/Snake Recognizer Project

# %%
version = 0
img_path = 'test data'
model_path = f'models/snake-recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)

# %%
img = Image.open(f'{img_path}/high.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/high.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Banded krait',
#  tensor(0),
#  tensor([9.9997e-01, 3.4077e-08, 4.3798e-08, 1.2929e-07, 3.8806e-06, 2.4784e-05,
#          6.7121e-08, 7.3726e-08, 9.5330e-07, 2.7526e-08, 1.0036e-07, 6.8805e-09,
#          1.4429e-07, 2.5506e-06, 5.0023e-08, 7.9886e-07, 4.1804e-07, 1.6621e-08]))

# %%
img = Image.open(f'{img_path}/viper-2.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/viper-2.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ("Russell's viper",
#  tensor(14),
#  tensor([1.3955e-06, 9.2155e-08, 2.0726e-08, 6.5074e-08, 1.0645e-05, 2.5260e-06,
#          2.7036e-08, 1.1746e-07, 2.7273e-07, 2.3606e-07, 1.0517e-06, 2.5985e-06,
#          1.9955e-06, 7.2265e-08, 9.9996e-01, 6.8991e-09, 1.4762e-05, 3.8072e-08]))

# %%
img = Image.open(f'{img_path}/download (6).jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/download (6).jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Rattle snake',
#  tensor(12),
#  tensor([2.5003e-10, 4.5960e-07, 2.0137e-08, 4.6428e-09, 3.5580e-07, 3.1230e-10,
#          3.6527e-10, 5.4273e-07, 3.3524e-09, 2.3515e-11, 1.0923e-10, 7.2258e-11,
#          1.0000e+00, 6.4009e-11, 3.2665e-08, 9.0552e-10, 9.2521e-08, 1.8496e-10]))

# %%
img = Image.open(f'{img_path}/4538a8531287f0a3ab464d0b9dd69744.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/4538a8531287f0a3ab464d0b9dd69744.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Samar cobra',
#  tensor(15),
#  tensor([7.4036e-06, 7.9969e-07, 1.7370e-05, 1.2326e-04, 4.2892e-07, 4.9698e-05,
#          2.0973e-04, 8.7293e-06, 1.0703e-04, 7.2915e-05, 1.1017e-06, 9.5329e-07,
#          5.1343e-06, 7.8569e-05, 3.5447e-05, 9.9926e-01, 9.8091e-07, 1.6629e-05]))
